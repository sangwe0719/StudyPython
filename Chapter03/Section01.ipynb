# %%
import numpy as np
a = np.ndarray(shape = (2,2), dtype = int)
b = np.ndarray(shape = (2,2), dtype = int)
b
# Out:
# array([[   4294967296,             0],
#        [          868, 1765231559424]])

# %%
import numpy as np
a = np.array([1,2,3],dtype=int)
a
type(a)
# Out:
# numpy.ndarray
