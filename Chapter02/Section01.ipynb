# %%
year = 2027
year
type(year)
s = "123"
type(s)
# Out:
# str

# %%
_25te = 25

# %%
import datetime as dt
c = dt.datetime.now()
print(c.year,c.month,c.day)
print(c.hour,c.minute,c.second)
type(c)
# Out:
# 2026 3 4
# 17 40 40
# datetime.datetime

# %%
10/7
True or False
# Out:
# True

# %%
# year = input('당신이 태어난 년도는?:') 
type(year)
print(year)
print('나이',year)
# Out:
# 1998
# 나이 1998

# %%
import math as m
m.pi,m.e
# Out:
# (3.141592653589793, 2.718281828459045)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\18616\anaconda3\python.exe

# %%
# %pip install pydataset seaborn
# Out:
# Collecting pydataset
#   Using cached pydataset-0.2.0.tar.gz (15.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: seaborn in c:\users\18616\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: pandas in c:\users\18616\anaconda3\lib\site-packages (from pydataset) (2.3.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\18616\anaconda3\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\18616\anaconda3\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\18616\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\18616\anaconda3\lib\site-packages (from pandas->pydataset) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\18616\anaconda3\lib\site-packages (from pandas->pydataset) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\18616\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (pyproject.toml): started
#   Building wheel for pydataset (pyproject.toml): finished with status 'done'
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939227 sha256=c73e5ffd7cc561692735f95a0f43def88c0fe10aa7341308b54d9823aeabb36c
#   Stored in directory: c:\users\18616\appdata\local\pip\cache\wheels\49\2a\45\180e1199b8d925b5c43df8f9850dcc2e5dfc94e3e99a55b83e
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data
all_data = data()
all_data
# Out:
# initiated datasets repo at: C:\Users\18616\.pydataset/
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
cars = data('cars')
cars
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27216\2771897798.py in ?()
#       1 cars = data('cars')
#       2 cars
# ----> 3 cars.dataset_id
#
# c:\Users\18616\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dataset_id'

# %%
import matplotlib.pyplot as plt 
plt.scatter(x = cars.speed, y = cars.dist)
plt.show()

# %%
mpg = data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
